# %%
import sympy as sp
from sympy import latex

# %%
D_L, w_L, gamma_L, vx_L, vy_L, vz_L,b0_L, bx_L, by_L, bz_L, p_L, Bx_L, By_L, Bz_L, h_L = sp.symbols('D^L w^L gamma^L v_x^L v_y^L v_z^L b0^L b_x^L b_y^L b_z^L p_L B_x^L B_y^L B_z^L h^L', real=True)
D_R, w_R, gamma_R, vx_R, vy_R, vz_R,b0_R, bx_R, by_R, bz_R, p_R, Bx_R, By_R, Bz_R, h_R = sp.symbols('D^R w^R gamma^R v_x^R v_y^R v_z^R b0^R b_x^R b_y^R b_z^R p_R B_x^R B_y^R B_z^R h^R', real=True)

# %%
mx_L, my_L, mz_L = sp.symbols('m_x^L m_y^L m_z^L', real=True)   
mx_R, my_R, mz_R = sp.symbols('m_x^R m_y^R m_z^R', real=True)   
cmax = sp.symbols('c_{max}', real=True)
cmin = sp.symbols('c_{min}', real=True)

# %%
R_L = cmax*D_L - D_L*vx_L
R_R = cmin*D_R - D_R*vx_R
FD_L = vx_L*D_L
Fmx_L = mx_L*
